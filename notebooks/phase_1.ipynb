# %%
import pypdf
from pathlib import Path

pdf_path = Path("../data/raw/Introduction_to_Python_Programming-WEB.pdf")

with open(pdf_path, "rb") as f:
    reader = pypdf.PdfReader(f)
    print(reader.pages[0].extract_text()[:500])

# %%
pdf_path = Path("../data/raw/Principles-of-Data-Science-WEB.pdf")

with open(pdf_path, "rb") as f:
    reader = pypdf.PdfReader(f)
    print(reader.pages[0].extract_text()[:500])
